# %% [markdown]
# Author: Dexter Y. Wu
# $$\textbf{Preprocessing Algerian Forest Fires Dataset Data Set}$$

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# df1 = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', header=1, nrows=122)
df1 = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', header = 1, nrows=122)
print(df1.info())
# print(df1.columns)

# df2 = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', skiprows=125)
# print(df2)
# df2 = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', header=1, skiprows=125)
# df1.columns = df1.columns.str.strip()#Stripping white spaces from column names
# df2.columns = df2.columns.str.strip()
# print("Bejaia Region Dataset")
# #print(df1.columns)
# print(df1.shape)
# print(df1.head())
# print("Sidi-Bel Abbes Region Dataset")
# #print(df1.columns)
# print(df2.shape)
# print(df2.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          2 non-null      int64
#  1   month        2 non-null      int64
#  2   year         2 non-null      int64
#  3   Temperature  2 non-null      int64
#  4    RH          2 non-null      int64
#  5    Ws          2 non-null      int64
#  6   Rain         2 non-null      float64
#  7   FFMC         2 non-null      float64
#  8   DMC          2 non-null      float64
#  9   DC           2 non-null      float64
#  10  ISI          2 non-null      float64
#  11  BUI          2 non-null      float64
#  12  FWI          2 non-null      float64
#  13  Classes      2 non-null      object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 352.0+ bytes
# None

# %% [markdown]
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %%
#removing null rows
df1 = df1.dropna()
df2 = df2.dropna()
#Drop the year since it is constant
df1 = df1.drop(['year'], axis=1)
df2 = df2.drop(['year'], axis=1)
#Match month to 0-based index
# df1['month'] = df1['month'] - 6
# df2['month'] = df2['month'] - 6
# print(df1.iloc[-1])
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   Temperature  122 non-null    int64
#  3   RH           122 non-null    int64
#  4   Ws           122 non-null    int64
#  5   Rain         122 non-null    float64
#  6   FFMC         122 non-null    float64
#  7   DMC          122 non-null    float64
#  8   DC           122 non-null    float64
#  9   ISI          122 non-null    float64
#  10  BUI          122 non-null    float64
#  11  FWI          122 non-null    float64
#  12  Classes      122 non-null    object
# dtypes: float64(7), int64(5), object(1)
# memory usage: 12.5+ KB
# None

# %%
#Aligning the data types to be the same as df1
df2['DC'] = df2['DC'].astype(float)
df2['FWI'] = df2['FWI'].astype(float)
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 0 to 121
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          121 non-null    int64
#  1   month        121 non-null    int64
#  2   Temperature  121 non-null    int64
#  3   RH           121 non-null    int64
#  4   Ws           121 non-null    int64
#  5   Rain         121 non-null    float64
#  6   FFMC         121 non-null    float64
#  7   DMC          121 non-null    float64
#  8   DC           121 non-null    float64
#  9   ISI          121 non-null    float64
#  10  BUI          121 non-null    float64
#  11  FWI          121 non-null    float64
#  12  Classes      121 non-null    object
# dtypes: float64(7), int64(5), object(1)
# memory usage: 13.2+ KB
# None

# %%
#standardizing the class labels
df1['Classes'] = df1['Classes'].str.lower().str.strip()
df2['Classes'] = df2['Classes'].str.lower().str.strip()
# Map the class labels to numerical values
class_dict = {'not fire': 0, 'fire': 1}
df1['Classes'] = df1['Classes'].map(class_dict)
df2['Classes'] = df2['Classes'].map(class_dict)

# %%
#Visualizing the data
class_count = df2['Classes'].value_counts()
# df1.plot(x='Classes', y=class_count, kind='bar')
# plt.show()
class_count
# Out:
# 1    78
# 0    43
# Name: Classes, dtype: int64

# %%
corr1 = df1.corr()
sns.heatmap(corr1, annot=True)

plt.show()

# %%
corr2 = df2.corr()
sns.heatmap(corr2, annot=True)

plt.show()
